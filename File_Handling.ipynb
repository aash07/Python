# %%
# Example of exception handling

a=int(input('Enter a:'))

while True:
    b=int(input('Enter b:'))
    try:
        x=a/b
        break
    except:
        print('Division by zero is not possible, Enter b again')
        
print('Division is: ',x)
print('Program over')
# Out:
# Enter a:10
# Enter b:5
# Division is:  2.0
# Program over

# %%
# Example to open a file and count number of lines in that file

try:
    fhand=open('myfile.txt','r')
    print('File opened successfully ')
except:
    print('File cannot be opened')
    exit()
    
count =0
for line in fhand:
    count+=1
    print("Line Number ",count, ":", line)

print("Total lines=",count)
fhand.close()          #closing file once the operations are over
# Out:
# File opened successfully
# Line Number  1 : hello how are you?
#
# Line Number  2 : I am doing fine!!
#
# Line Number  3 : how# about you?
#
# Line Number  4 : hello world How
#
# Line Number  5 : karnataka is a state in India
#
# Line Number  6 : Bangalroe is capital of Karnataka
#
# Line Number  7 : hello how are you?
#
# Line Number  8 : I am doing fine!!
#
# Line Number  9 : how# about you?
#
# Line Number  10 : hello world How
#
# Line Number  11 : karnataka is a state in India
#
# Line Number  12 : Bangalroe is capital of Karnataka
#
# Line Number  13 : hello how are you?
#
# Line Number  14 : I am doing fine!!
#
# Line Number  15 : how# about you?
#
# Line Number  16 : hello world How
#
# Line Number  17 : karnataka is a state in India
#
# Line Number  18 : Bangalroe is capital of Karnataka
#
# Line Number  19 : hello how are you?
#
# Line Number  20 : I am doing fine!!
#
# Line Number  21 : how# about you?
#
# Line Number  22 : hello world How
#
# Line Number  23 : karnataka is a state in India
#
# Line Number  24 : Bangalroe is capital of Karnataka
#
# Line Number  25 : hello how are you?
#
# Line Number  26 : I am doing fine!!
#
# Line Number  27 : how# about you?
#
# Line Number  28 : hello world How
#
# Line Number  29 : karnataka is a state in India
#
# Line Number  30 : Bangalroe is capital of Karnataka
#
# Line Number  31 : hello how are you?
#
# Line Number  32 : I am doing fine!!
#
# Line Number  33 : how# about you?
#
# Line Number  34 : hello world How
#
# Line Number  35 : karnataka is a state in India
#
# Line Number  36 : Bangalroe is capital of Karnataka
#
# Line Number  37 : hello how are you?
#
# Line Number  38 : I am doing fine!!
#
# Line Number  39 : how# about you?
#
# Line Number  40 : hello world How
#
# Line Number  41 : karnataka is a state in India
#
# Line Number  42 : Bangalroe is capital of Karnataka
#
# Total lines= 42

# %%
fhand=open('myfile.txt')
s= fhand.read()
print(len(s))

# %%
# Usage of read() function. This will read whole file as a single string and
# store it into a variable of the program

try:
    fhand=open('myfile.txt')
except:
    print('File cannot be opened.')
    exit()
    
s=fhand.read()
print(len(s))   #counting number of characters in the file
print('The file contents are: ',s)
print('The first 20 characters of the file are:',s[:20])
fhand.close()
# Out:
# 931
# The file contents are:  hello how are you?
# I am doing fine!!
# how# about you?
# hello world How
# karnataka is a state in India
# Bangalroe is capital of Karnataka
# hello how are you?
# I am doing fine!!
# how# about you?
# hello world How
# karnataka is a state in India
# Bangalroe is capital of Karnataka
# hello how are you?
# I am doing fine!!
# how# about you?
# hello world How
# karnataka is a state in India
# Bangalroe is capital of Karnataka
# hello how are you?
# I am doing fine!!
# how# about you?
# hello world How
# karnataka is a state in India
# Bangalroe is capital of Karnataka
# hello how are you?
# I am doing fine!!
# how# about you?
# hello world How
# karnataka is a state in India
# Bangalroe is capital of Karnataka
# hello how are you?
# I am doing fine!!
# how# about you?
# hello world How
# karnataka is a state in India
# Bangalroe is capital of Karnataka
# hello how are you?
# I am doing fine!!
# how# about you?
# hello world How
# karnataka is a state in India
# Bangalroe is capital of Karnataka
#
# The first 20 characters of the file are: hello how are you?
# I

# %%
# Example to write the data into a file

fout=open('f1.txt','w')

for i in range(5):
    line=input("Enter a line: ")
    fout.write(line +"\n")

print('File writing over!!')
fout.close()

# %%
# Write a program to count number of words in the file

try:
    fhand=open('myfile.txt','r')
    print('File opened successfully ')
except:
    print('File cannot be opened')
    exit()
    
count =0
for line in fhand:
    count+=len(line.split())
    print("Line Number ",count, ":", line)

print("Total words=",count)
fhand.close()

# %%
# Searching for a word and print only those lines which starts with the given word

fname=input('Enter a file name:')
word=input('Enter a word to be searched:')

try:
    fhand=open(fname, 'r')
    for line in fhand:
        if line.startswith(word):
            print(line)
            
    fhand.close()
except:
    print('File cannot be opened')

# %%
# Program to cound number of lines, words, characters in a file

file=input("Enter a file name:")
try:
    fhand=open(file)
except:
    print("File not found")
    exit(0)

lineCount=0
wordCount=0
charCount=0
for line in fhand:
    lineCount+=1
    charCount+=len(line)
    ls=line.split()
    wordCount+=len(ls)

print('Number of lines=',lineCount)
print('Number of words=', wordCount)
print('Number of characters=', charCount)
fhand.close()

# %%
# Write a program to copy contents of one file into another

#file=input("Enter a file name:")

try:
    fhand1=open('D:\Chetana_Workspace\myfile.txt')
except:
    print("File not found")
    exit(0)

fhand2=open('destFile.txt','w')
for line in fhand1:
    fhand2.write(line)

print('File copied successfully')
fhand1.close()
fhand2.close()

# %%
# Write a program to display first 10 and last 10 lines of a file

#file=input("Enter a file name:")
try:
    fhand=open('D:\\Chetana_Workspace\\myfile.txt')
except:
    print("File not found")
    exit(0)

s=fhand.read()        #s stores whole file contents
ls=s.split('\n')      #split s based on new-line character

print('\nFirst 10 lines are:')
for i in ls[:10]:
    print(i)

print('\nLast 10 lines are:')
for i in ls[-10:]:
    print(i)

fhand.close()
